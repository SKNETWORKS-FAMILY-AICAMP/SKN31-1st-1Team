# %%
import csv


with open('kcar_cars_raw.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    data = list(reader)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3
#       4 with open('kcar_cars_raw.csv', 'r') as f:
#       5     reader = csv.reader(f)
# ----> 6     data = list(reader)
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 6: illegal multibyte sequence
